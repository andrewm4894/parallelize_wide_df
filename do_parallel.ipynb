# %%
import pandas as pd
import seaborn as sns
from my_functions import parallelize_dataframe, do_work

# %%
df = pd.DataFrame(sns.load_dataset('iris'))
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_out = parallelize_dataframe(df, do_work, col_subsets=[['sepal_length','sepal_width'],['petal_length','petal_width']])

# %%
df_out.head(10)
# Out:
#    sepal_length  sepal_width  sepal_length_squared  sepal_length_sqrt  \
# 0           5.1          3.5                 26.01           2.258318
# 1           4.9          3.0                 24.01           2.213594
# 2           4.7          3.2                 22.09           2.167948
# 3           4.6          3.1                 21.16           2.144761
# 4           5.0          3.6                 25.00           2.236068
# 5           5.4          3.9                 29.16           2.323790
# 6           4.6          3.4                 21.16           2.144761
# 7           5.0          3.4                 25.00           2.236068
# 8           4.4          2.9                 19.36           2.097618
# 9           4.9          3.1                 24.01           2.213594
#
#    sepal_width_squared  sepal_width_sqrt  petal_length  petal_width  \
# 0                12.25          1.870829           1.4          0.2
# ...
